# %%
from quantrocket.master import get_securities

# %%
get_securities?
# Out:
# Signature:
# get_securities(
#     symbols=None,
#     exchanges=None,
#     sec_types=None,
#     currencies=None,
#     universes=None,
#     sids=None,
#     exclude_universes=None,
#     exclude_sids=None,
#     exclude_delisted=False,
#     exclude_expired=False,
#     frontmonth=False,
#     vendors=None,
#     fields=None,
# )
# Docstring:
# Return a DataFrame of security details from the securities master database.
#
# Parameters
# ----------
# symbols : list of str, optional
#     limit to these symbols
#
# exchanges : list of str, optional
#     limit to these exchanges. You can specify exchanges using the MIC or the
#     vendor's exchange code.
#
# sec_types : list of str, optional
#     limit to these security types. Possible choices: STK, ETF, FUT, CASH, IND, OPT, FOP, BAG
#
# currencies : list of str, optional
#     limit to these currencies
#
# universes : list of str, optional
#     limit to these universes
#
# sids : list of str, optional
#     limit to these sids
# ...

# %%
get_securities(symbols=['SI', 'ASAN', 'DNPLY', 'HCM'], sec_types="STK", currencies=["USD"], exclude_delisted=True)
# Out:
#                Symbol Exchange Country Currency SecType    Etf  \
# Sid
# FIBBG000BV1RB5  DNPLY     XOTC      US      USD     STK  False
# FIBBG00B6VCGJ1    HCM     XNAS      US      USD     STK  False
# FIBBG00MMM95S7     SI     XNYS      US      USD     STK  False
# FIBBG00WYHL732   ASAN     XNYS      US      USD     STK  False
#
#                         Timezone                          Name  \
# Sid
# FIBBG000BV1RB5  America/New_York    Dai Nippon Printing Co Ltd
# FIBBG00B6VCGJ1  America/New_York  HUTCHISON CHINA MEDITECH-ADR
# FIBBG00MMM95S7  America/New_York  SILVERGATE CAPITAL CORP-CL A
# FIBBG00WYHL732  America/New_York              ASANA INC - CL A
#
#                 PriceMagnifier  Multiplier  Delisted DateDelisted  \
# Sid
# FIBBG000BV1RB5               1           1     False          NaT
# FIBBG00B6VCGJ1               1           1     False          NaT
# FIBBG00MMM95S7               1           1     False          NaT
# ...

# %%
get_securities(symbols=['SI', 'ASAN', 'DNPLY', 'HCM'], sec_types="STK", currencies=["USD"], exclude_delisted=True).index.values
# Out:
# array(['FIBBG000BV1RB5', 'FIBBG00B6VCGJ1', 'FIBBG00MMM95S7',
#        'FIBBG00WYHL732'], dtype=object)
